# %%
cd("/mnt/juliabox/.ssh")
run(`ls -la .`)
run(`ls -la  /home/jrun/.ssh`)
run(`cp -Rf /mnt/juliabox/.ssh/id_rsa /home/jrun/.ssh `)
run(`cp -Rf /mnt/juliabox/.ssh/id_rsa.pub /home/jrun/.ssh `)
run(`cp -Rf /mnt/juliabox/.ssh/known_hosts /home/jrun/.ssh `)
#run(`chmod g-w,o-w /home/jrun/.ssh/id_rsa `)
run(`chmod 400 /home/jrun/.ssh/id_rsa `)
run(`ls -la  /home/jrun/.ssh`)
run(`echo ~~~ ----------------------------------------------- `)

cd("/mnt/juliabox/JuliaBox_Sync")
run(`pwd`)
run(`ls -al `)

run(`git log `)
run(`git pull `)
#run(`git add . `)    # stage all changed files in directory .
#run(`git commit -m "first commit" `)
run(`git add tryGitMerge.ipynb `)    # stage all changed files in directory .
run(`git commit -m "workflow to sync with github repo" `)

run(`git push origin master`)
# Out:
# total 3
# drwxrwxrwx 2 root root    0 Nov 14  2017 .
# drwxrwxrwx 2 root root    0 Nov 14  2017 ..
# -rwxrwxrwx 1 root root 1675 Nov 14  2017 id_rsa
# -rwxrwxrwx 1 root root  415 Nov 14  2017 id_rsa.pub
# -rwxrwxrwx 1 root root  392 Apr  8 02:35 known_hosts
# total 24
# drwx------ 2 jrun jrun 4096 Apr  8 03:17 .
# drwxr-xr-x 1 jrun jrun 4096 Apr  8 02:40 ..
# -r-------- 1 jrun jrun 1675 Apr  8 03:17 id_rsa
# -rwxr-xr-x 1 jrun jrun  415 Apr  8 03:17 id_rsa.pub
# -rwxr-xr-x 1 jrun jrun 1276 Apr  8 03:22 known_hosts
# total 24
# drwx------ 2 jrun jrun 4096 Apr  8 03:41 .
# drwxr-xr-x 1 jrun jrun 4096 Apr  8 02:40 ..
# -r-------- 1 jrun jrun 1675 Apr  8 03:41 id_rsa
# -rwxr-xr-x 1 jrun jrun  415 Apr  8 03:41 id_rsa.pub
# -rwxr-xr-x 1 jrun jrun  392 Apr  8 03:41 known_hosts
# ~~~ -----------------------------------------------
# /mnt/juliabox/JuliaBox_Sync
# total 25508
# drwxrwxrwx 2 root root        0 Apr  8 02:35 .
# drwxrwxrwx 2 root root        0 Nov 14  2017 ..
# ...

# %%
run(`git log `)
run(`git pull `)
#run(`git add . `)    # stage all changed files in directory .
#run(`git commit -m "first commit" `)
run(`git add tryGitMerge.ipynb `)    # stage all changed files in directory .
run(`git commit -m "workflow to sync with github repo" `)

run(`git push origin master`)
# Out:
# commit dd641463a716c23502f95bcc9ea464b5365fe5bd
# Author: tlyim <acdryim@gmail.com>
# Date:   Mon Apr 8 03:22:55 2019 +0000
#
#     first commit
#
# commit 37b6b7b70f11b70d119a741d9ebdc6181a4248b1
# Author: Tl Yim <acdryim@gmail.com>
# Date:   Wed Mar 28 18:29:24 2018 +0100
#
#     add Tutorial.ipnb
#
# commit de231a24f1224552b1070281aca4b1db622555c3
# Author: tlyim <tlyim@users.noreply.github.com>
# Date:   Sun Sep 10 21:45:59 2017 +0100
#
#     Initial commit
# Already up-to-date.
# Everything up-to-date
# Process(`git push origin master`, ProcessExited(0))

# %%
#run(`man ssh-add`)
#run(`ssh-agent -k `)
cd("/mnt/juliabox/.ssh")
#run(`ls -la ../`)
run(`ls -la .`)
run(`ls -la  /home/jrun/.ssh`)
run(`cp -Rf /mnt/juliabox/.ssh/id_rsa /home/jrun/.ssh `)
run(`cp -Rf /mnt/juliabox/.ssh/id_rsa.pub /home/jrun/.ssh `)
run(`cp -Rf /mnt/juliabox/.ssh/known_hosts /home/jrun/.ssh `)
#run(`chmod g-w,o-w /home/jrun/.ssh/id_rsa `)
run(`chmod 400 /home/jrun/.ssh/id_rsa `)
run(`ls -la  /home/jrun/.ssh`)
# Out:
# total 3
# drwxrwxrwx 2 root root    0 Nov 14  2017 .
# drwxrwxrwx 2 root root    0 Nov 14  2017 ..
# -rwxrwxrwx 1 root root 1675 Nov 14  2017 id_rsa
# -rwxrwxrwx 1 root root  415 Nov 14  2017 id_rsa.pub
# -rwxrwxrwx 1 root root  392 Apr  8 02:35 known_hosts
# total 24
# drwx------ 2 jrun jrun 4096 Apr  8 02:56 .
# drwxr-xr-x 1 jrun jrun 4096 Apr  8 02:40 ..
# -rwxr-xr-x 1 jrun jrun 1675 Apr  8 03:09 id_rsa
# -rwxr-xr-x 1 jrun jrun  415 Apr  8 03:09 id_rsa.pub
# -rwxr-xr-x 1 jrun jrun  834 Apr  8 03:09 known_hosts
# total 24
# drwx------ 2 jrun jrun 4096 Apr  8 02:56 .
# drwxr-xr-x 1 jrun jrun 4096 Apr  8 02:40 ..
# -r-------- 1 jrun jrun 1675 Apr  8 03:15 id_rsa
# -rwxr-xr-x 1 jrun jrun  415 Apr  8 03:15 id_rsa.pub
# -rwxr-xr-x 1 jrun jrun  392 Apr  8 03:15 known_hosts
# Process(`ls -la /home/jrun/.ssh`, ProcessExited(0))

# %%
cd("/mnt/juliabox/.ssh")
run(`ls -la .`)
run(`cat id_rsa.pub`)  # this part goes to GitHub
run(`echo ~~~ ----------------------------------------------- `)
run(`cat id_rsa`)
run(`echo ~~~ ----------------------------------------------- `)
run(`cat known_hosts`)
run(`echo ~~~ ----------------------------------------------- `)

cd("/mnt/juliabox/.ssh")
run(`ls -la .`)
run(`ls -la  /home/jrun/.ssh`)
run(`cp -Rf /mnt/juliabox/.ssh/id_rsa /home/jrun/.ssh `)
run(`cp -Rf /mnt/juliabox/.ssh/id_rsa.pub /home/jrun/.ssh `)
run(`cp -Rf /mnt/juliabox/.ssh/known_hosts /home/jrun/.ssh `)
#run(`chmod g-w,o-w /home/jrun/.ssh/id_rsa `)
run(`chmod 400 /home/jrun/.ssh/id_rsa `)
run(`ls -la  /home/jrun/.ssh`)

run(`echo ~~~ ----------------------------------------------- `)
cd("/mnt/juliabox/JuliaBox_Sync")
run(`git log `)
#run(`git pull `)


#run(`ssh-agent -s`)
#run(`ssh-add -l`) # -E md5`)
#run(`ssh-agent -k`)

#run(`ssh-add -l`) # -E md5`)

run(`ls -la /home/jrun`)
run(`ls -la /mnt/juliabox/.ssh`)

#run(`ls -la /home/jrun/.ssh`)
#/home/jrun/.ssh/id_rsa
run(`echo ~~~ ----------------------------------------------- `)
run(`ssh -vT git@github.com`)

run(`echo ----------------------------------------------- `)
#run(`ls -la `)
#run(`git remote -v `)  # Verifies the new remote URL
#### run(`git remote add origin https://github.com/tlyim/JuliaBox_Sync.git `)    # Sets the new remote

run(`git config --global user.email `)
run(`echo ----------------------------------------------- `)
#run(`ls -la .git`)

#run(`git config --global user.name "Tl Yim" `)  #chmod on /mnt/juliabox/.gitconfig.lock failed: Operation not permitted
run(`git config user.name  `)
#run(`git config user.name "tlyim" `)  # can only set local repo user.name, unless remount by su

run(`echo ----------------------------------------------- `)
run(`git add . `)
run(`echo ----------------------------------------------- `)

#run(`git commit -m "first commit" `)
#run(`git push origin master`)
#
#run(`git init `)
# Out:
# total 3
# drwxrwxrwx 2 root root    0 Nov 14  2017 .
# drwxrwxrwx 2 root root    0 Nov 14  2017 ..
# -rwxrwxrwx 1 root root 1675 Nov 14  2017 id_rsa
# -rwxrwxrwx 1 root root  415 Nov 14  2017 id_rsa.pub
# -rwxrwxrwx 1 root root  392 Apr  8 02:35 known_hosts
# ssh-rsa  jrun@ssh2658452421806934645-vhqmv
# ~~~ -----------------------------------------------
# -----BEGIN RSA PRIVATE KEY-----
# MIIEogIBAAKCAQEAzXbWmnxBKb82CxyCLlBlW1Zrv+/0XHyAVWWvoihLKGrzyxFC
# Mo8jp3nDsSPDLk9Wrx9Kgf/GVvdWW7yyne02ncsKDdFBYfzeHE/YPqqFqRqKp/Ku
# JYkLD/Bc21UBAlpdQeix4xYNh0pmU/LKvxcn9oHWd4BcmIjxrHt9SLvvGpm6eaQ4
# ...

# %%
cd("/mnt/juliabox")
run(`pwd`)

#run(`cp -r JuliaBox_Sync JuliaBox_Sync_bak`)
run(`ls -al `)
cd("/mnt/juliabox/JuliaBox_Sync_bak")
run(`pwd`)
run(`ls -al `)
cd("/mnt/juliabox/JuliaBox_Sync_bak/.git")
run(`pwd`)
run(`ls -al `)

run(`echo ----------------------------------------------- `)
run(`git remote -v`)

#test0 = "[core]\n\trepositoryformatversion = 0\n\tfilemode = true\n\tbare = false\n\tlogallrefupdates = true\n[remote \"origin\"]\n\turl = https://github.com/tlyim/JuliaBox_Sync.git\n\tfetch = +refs/heads/*:refs/remotes/origin/*\n[branch \"master\"]\n\tremote = origin\n\tmerge = refs/heads/master\n"
#test2 = "[core]\n\trepositoryformatversion = 0\n\tfilemode = true\n\tbare = false\n\tlogallrefupdates = true\n[remote \"origin\"]\n\turl = git@github.com:tlyim/JuliaBox_Sync.git\n\tfetch = +refs/heads/*:refs/remotes/origin/*\n[branch \"master\"]\n\tremote = origin\n\tmerge = refs/heads/master\n"
#io = open("config_ssh", "a")
#write(io, test2)
#close(io)

#run(`cp ./config_  ./config`)


run(`echo ----------------------------------------------- `)
io = open("config", "r")
read(io, String)
run(`echo ----------------------------------------------- `)
close(io)

run(`cat config`)
run(`echo ----------------------------------------------- `)
#run(`git remote set-url origin git@github.com:tlyim/JuliaBox_Sync.git`)
run(`git remote -v`)
# Out:
# /mnt/juliabox
# total 450
# drwxrwxrwx 2 root root      0 Nov 14  2017 .
# drwxr-xr-x 1 root root   4096 Apr  7 23:46 ..
# drwxrwxrwx 2 root root      0 Apr  7 00:02 .cache
# drwxrwxrwx 2 root root      0 Apr  7 00:02 .config
# drwxrwxrwx 2 root root      0 Apr  7 00:02 .fontconfig
# -rwxrwxrwx 1 root root     51 Apr  7 23:01 .gitconfig
# drwxrwxrwx 2 root root      0 May  6  2018 .ipynb_checkpoints
# drwxrwxrwx 2 root root      0 Mar 28 22:13 .ipython
# drwxrwxrwx 2 root root      0 Dec 15 13:04 .julia
# -rwxrwxrwx 1 root root      3 Apr  7 15:40 .julia_master_version
# drwxrwxrwx 2 root root      0 May  6  2018 .local
# drwxrwxrwx 2 root root      0 Nov 14  2017 .ssh
# -rwxrwxrwx 1 root root  10905 Apr  7 01:51 IPythonYouRWeJulia_jl.ipynb
# -rwxrwxrwx 1 root root   5856 Apr  7 04:26 InstallR_library.ipynb
# -rwxrwxrwx 1 root root   1021 Mar 28 22:20 Julia 1.0.3 (4 threads).ipynb
# drwxrwxrwx 2 root root      0 Apr  7 20:49 JuliaBox_Sync
# ...

# %%
cd("/mnt/juliabox/JuliaBox_Sync")
run(`git config user.name  `)
run(`ls -al ..`)
run(`ls -al ../.ssh `)

run(`git remote -v`)
#run(`git remote set-url origin git@github.com:tlyim/JuliaBox_Sync.git`)
run(`git remote -v`)

#run(`git push origin master`)
# Out:
# 'Tl Yim'
# total 447
# drwxrwxrwx 2 root root      0 Nov 14  2017 .
# drwxr-xr-x 1 root root   4096 Apr  7 22:52 ..
# drwxrwxrwx 2 root root      0 Apr  7 00:02 .cache
# drwxrwxrwx 2 root root      0 Apr  7 00:02 .config
# drwxrwxrwx 2 root root      0 Apr  7 00:02 .fontconfig
# -rwxrwxrwx 1 root root     51 Apr  7 23:01 .gitconfig
# drwxrwxrwx 2 root root      0 May  6  2018 .ipynb_checkpoints
# drwxrwxrwx 2 root root      0 Mar 28 22:13 .ipython
# drwxrwxrwx 2 root root      0 Dec 15 13:04 .julia
# -rwxrwxrwx 1 root root      3 Apr  7 15:40 .julia_master_version
# drwxrwxrwx 2 root root      0 May  6  2018 .local
# drwxrwxrwx 2 root root      0 Nov 14  2017 .ssh
# -rwxrwxrwx 1 root root  10905 Apr  7 01:51 IPythonYouRWeJulia_jl.ipynb
# -rwxrwxrwx 1 root root   5856 Apr  7 04:26 InstallR_library.ipynb
# -rwxrwxrwx 1 root root   1021 Mar 28 22:20 Julia 1.0.3 (4 threads).ipynb
# drwxrwxrwx 2 root root      0 Apr  7 20:49 JuliaBox_Sync
# ...

# %%
run(`git --version`)
run(`git log --help`)

run(`man rsync`)

run(`echo ` & `echo `)
# Out:
# git version 2.7.4
# GIT-LOG(1)                        Git Manual                        GIT-LOG(1)
#
# NAME
#        git-log - Show commit logs
#
# SYNOPSIS
#        git log [<options>] [<revision range>] [[--] <path>...]
#
# DESCRIPTION
#        Shows the commit logs.
#
#        The command takes options applicable to the git rev-list command to
#        control what is shown and how, and options applicable to the git diff-*
#        commands to control how the changes each commit introduces are shown.
#
# OPTIONS
#        --follow
#            Continue listing the history of a file beyond renames (works only
#            for a single file).
#
#        --no-decorate, --decorate[=short|full|no]
#            Print out the ref names of any commits that are shown. If short is
#            specified, the ref name prefixes refs/heads/, refs/tags/ and
#            refs/remotes/ will not be printed. If full is specified, the full
# ...

# %%
pwd()
run(`ls -la JuliaBox_Sync`)
run(`rm -Rf /home/jrun/JuliaBox_Sync`)
run(`ls -la /home/jrun`)

run(`echo ` & `echo `)
# Out:
# ls: cannot access 'JuliaBox_Sync': No such file or directory
# failed process: Process(`ls -la JuliaBox_Sync`, ProcessExited(2)) [2]
#
# Stacktrace:
#  [1] error(::String, ::Base.Process, ::String, ::Int64, ::String) at ./error.jl:42
#  [2] pipeline_error at ./process.jl:705 [inlined]
#  [3] #run#503(::Bool, ::Function, ::Cmd) at ./process.jl:663
#  [4] run(::Cmd) at ./process.jl:661
#  [5] top-level scope at In[8]:2

# %%
cd("/mnt/juliabox")
run(`cat .gitconfig`)
# Out:
# [user]
# 	email = acdryim@gmail.com
# 	name = 'tlyim'
# Process(`cat .gitconfig`, ProcessExited(0))

# %%
#cd("/home/jrun/JuliaBox_Sync")
#run(`ls -la .git`)


#run(`man git   `)
#run(`git  config --local`)

#run(`git  config --local -l`)
run(`echo ----------------------------------------------- `)

#run(`git  config --global -l`)
run(`echo ----------------------------------------------- `)
#run(`git config --global user.mail  `)
#run(`git  config --local --add user.name:"tlyim"`)

#run(`ls -la /home/jrun`)
run(`echo /mnt/juliabox`)
run(`ls -la /mnt/juliabox`)
#run(`ls -la /home/jrun/.config/configstore`)
cd("/mnt/juliabox")
run(`cat .gitconfig`)

#close(io)

run(`echo ----------------------------------------------- `)

test2 = "[user]\n\temail = acdryim@gmail.com\n\tname = 'tlyim'\n"
#test2 = "\tname = 'Tl Yim'\n"
io = open(".gitconfig", "w")
write(io, test2)
close(io)
run(`echo ----------------------------------------------- `)
run(`cat .gitconfig`)

run(`echo ----------------------------------------------- `)
io = open(".gitconfig", "r")
read(io, String)
close(io)


#run(`git  config --local -l`)
# Out:
# -----------------------------------------------
# -----------------------------------------------
# /mnt/juliabox
# total 456
# drwxrwxrwx 2 root root      0 Nov 14  2017 .
# drwxr-xr-x 1 root root   4096 Apr  7 23:46 ..
# drwxrwxrwx 2 root root      0 Apr  7 00:02 .cache
# drwxrwxrwx 2 root root      0 Apr  7 00:02 .config
# drwxrwxrwx 2 root root      0 Apr  7 00:02 .fontconfig
# -rwxrwxrwx 1 root root    101 Apr  8 00:38 .gitconfig
# -rwxrwxrwx 1 root root     50 Apr  8 00:47 .gitconfig_
# -rwxrwxrwx 1 root root     50 Apr  8 00:46 .gitconfig_new
# drwxrwxrwx 2 root root      0 May  6  2018 .ipynb_checkpoints
# drwxrwxrwx 2 root root      0 Mar 28 22:13 .ipython
# drwxrwxrwx 2 root root      0 Dec 15 13:04 .julia
# -rwxrwxrwx 1 root root      3 Apr  7 15:40 .julia_master_version
# drwxrwxrwx 2 root root      0 May  6  2018 .local
# drwxrwxrwx 2 root root      0 Nov 14  2017 .ssh
# -rwxrwxrwx 1 root root  10905 Apr  7 01:51 IPythonYouRWeJulia_jl.ipynb
# ...

# %%
cd("/home/jrun")
#run(`git clone https://github.com/tlyim/JuliaBox_Sync.git`)
run(`git config --global user.email `)
run(`git config --global user.name `)
run(`echo ----------------------------------------------- `)
#run(`ls -la .git`)
run(`pwd`)
run(`ls -la`)

cd("/home/jrun/JuliaBox_Sync")
run(`git remote -v`)
run(`git remote set-url origin git@github.com:tlyim/JuliaBox_Sync.git`)
run(`git remote -v`)

cd("/mnt/juliabox")
run(`pwd`)
run(`ls -la`)
run(`cp -Rf /home/jrun/JuliaBox_Sync /mnt/juliabox `)

#cd("/mnt/juliabox")
#run(`ls -la `)
#run(`echo $ENV["PATH"]`)
#run(`echo $ENV["HOME"] `)

run(`echo ` & `echo `)
# Out:
# acdryim@gmail.com
# 'tlyim'
# -----------------------------------------------
# /home/jrun
# total 68
# drwxr-xr-x 1 jrun jrun 4096 Apr  8 01:05 .
# drwxr-xr-x 1 root root 4096 Feb 17 08:31 ..
# -rw-r--r-- 1 jrun jrun  220 Aug 31  2015 .bash_logout
# -rw-r--r-- 1 jrun jrun 3795 Feb 17 08:31 .bashrc
# drwxr-xr-x 1 jrun jrun 4096 Feb 17 09:48 .cache
# drwxr-xr-x 1 jrun jrun 4096 Feb 17 10:11 .cmake
# drwxr-xr-x 1 jrun jrun 4096 Feb 17 10:10 .config
# drwxr-xr-x 1 jrun jrun 4096 Feb 18 10:23 .julia
# drwxr-xr-x 1 jrun jrun 4096 Feb 17 09:27 .jupyter
# drwxr-xr-x 1 jrun jrun 4096 Feb 17 09:29 .keras
# drwxr-xr-x 1 jrun jrun 4096 Feb 17 10:10 .npm
# -rw-r--r-- 1 jrun jrun  655 May 16  2017 .profile
# drwxr-xr-x 3 jrun jrun 4096 Apr  8 01:05 JuliaBox_Sync
# -rwxrwxrwx 1 jrun jrun 2665 Jan 25 14:23 juliarc_tmpl.jl
# origin	git@github.com:tlyim/JuliaBox_Sync.git (fetch)
# origin	git@github.com:tlyim/JuliaBox_Sync.git (push)
# origin	git@github.com:tlyim/JuliaBox_Sync.git (fetch)
# ...

# %%
using PyCall,RCall;
R"""
.libPaths(c("/mnt/juliabox/R_library", .libPaths()))
print(.libPaths())
print(sessionInfo())
""";

# %%
# Code in Chapter 9\shell.jl:
   cmd = `echo Julia is smart`
typeof(cmd) #> Cmd 
    run(cmd) # returns Julia is smart
    run(`date`) #> Sun Oct 12 09:44:50 GMT 2014
cmd = `cat file1.txt`
run(cmd) ...

# %%
run(cmd)

# %%
run(`date`) 
#run(`man quota`)
run(`ls -la`)

# %%
run(`echo hello`)
run(`du -sh `)
#run(`du ./`)
run(`man du `)

# %%
ENV["HOME"]
#outfile = ENV["HOME"]*"/run_rstan.R"
outfile = ENV["HOME"]*"/tutorials"
run(`du -sh $outfile`)
#mypath = "show_a_path"
run(`set mypath = "show_a_path"`)
run(`echo $mypath`)
run(`quota -vs`)
#run(`ls` |> "out.log")
#run("out.log" |> `cat`)

# %%
run(`cp run_rstan.R  mytempfile`)
run(pipeline(`cat mytempfile`))
run(pipeline(`tail -n5`))
#run(pipeline(`cat mytempfile`, `tail -n5`))

#see https://docs.julialang.org/en/v0.7/manual/running-external-programs/

# %%
R"""
1+1.2
source("/mnt/juliabox/run_rstan.R")
""";

# %%
using RCall;
R"""

.libPaths(c("/mnt/juliabox/R_library", .libPaths()))
print(.libPaths())
print(sessionInfo())

#library(dplyr)
library(magrittr)

source("/mnt/juliabox/tryStan_2.R")
""";
# Out:
# [1] "/mnt/juliabox/R_library"       "/usr/local/lib/R/site-library"
# [3] "/usr/lib/R/site-library"       "/usr/lib/R/library"
# R version 3.4.4 (2018-03-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 16.04.5 LTS
#
# Matrix products: default
# BLAS: /usr/lib/libblas/libblas.so.3.6.0
# LAPACK: /usr/lib/lapack/liblapack.so.3.6.0
#
# locale:
# [1] C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# loaded via a namespace (and not attached):
# [1] compiler_3.4.4
#
# SAMPLING FOR MODEL 'simu_GP' NOW (CHAIN 1).
# Chain 1: Iteration: 1 / 1 [100%]  (Sampling)
# Chain 1:
# Chain 1:  Elapsed Time: 0 seconds (Warm-up)
# Chain 1:                3.1e-05 seconds (Sampling)
# Chain 1:                3.1e-05 seconds (Total)
# Chain 1:
#  [1] "G_total"     "M"           "N"           "Z"           "a"
#  [6] "alpha_T"     "avec"        "g"           "integrity"   "mod_OLS"
# ...

# %%
using RCall;
R"""

.libPaths(c("/mnt/juliabox/R_library", .libPaths()))
print(.libPaths())
print(sessionInfo())

library(magrittr)

library(rstan)
# The following can affect distributional computing over a cluster
#options(mc.cores = 1)  # only 1 core on Juliabox; don't set more unless 2-core machine is launched

source("/mnt/juliabox/tryStan_2.R")
""";
# Out:
# [1] "/mnt/juliabox/R_library"       "/usr/local/lib/R/site-library"
# [3] "/usr/lib/R/site-library"       "/usr/lib/R/library"
# R version 3.4.4 (2018-03-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 16.04.5 LTS
#
# Matrix products: default
# BLAS: /usr/lib/libblas/libblas.so.3.6.0
# LAPACK: /usr/lib/lapack/liblapack.so.3.6.0
#
# locale:
# [1] C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# loaded via a namespace (and not attached):
# [1] compiler_3.4.4
# ┌ Warning: RCall.jl: Loading required package: ggplot2
# │ Loading required package: StanHeaders
# │ rstan (Version 2.18.2, GitRev: 2e1f913d3ca3)
# │ For execution on a local, multicore CPU with excess RAM we recommend calling
# │ options(mc.cores = parallel::detectCores()).
# │ To avoid recompilation of unchanged Stan programs, we recommend calling
# │ rstan_options(auto_write = TRUE)
# │
# │ Attaching package: 'rstan'
# │
# ...

# %%
#using RCall;
# 4 threads (1 core) time shown
#   user  system elapsed 
#  3.597   0.003   3.718 

R"""

.libPaths(c("/mnt/juliabox/R_library", .libPaths()))
print(.libPaths())
print(sessionInfo())

library(magrittr)

library(rstan)
# The following can affect distributional computing over a cluster
#options(mc.cores = 1)  # only 1 core on Juliabox; don't set more unless 2-core machine is launched

source("/mnt/juliabox/tryStan_2.R")
""";
# Out:
# [1] "/mnt/juliabox/R_library"       "/usr/local/lib/R/site-library"
# [3] "/usr/lib/R/site-library"       "/usr/lib/R/library"
# R version 3.4.4 (2018-03-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 16.04.5 LTS
#
# Matrix products: default
# BLAS: /usr/lib/libblas/libblas.so.3.6.0
# LAPACK: /usr/lib/lapack/liblapack.so.3.6.0
#
# locale:
# [1] C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] rstan_2.18.2       StanHeaders_2.18.1 ggplot2_3.1.0      magrittr_1.5
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.1         tidyselect_0.2.5   munsell_0.5.0      colorspace_1.4-1
#  [5] R6_2.4.0           rlang_0.3.3        plyr_1.8.4         dplyr_0.8.0.1
#  [9] tools_3.4.4        parallel_3.4.4     pkgbuild_1.0.3     grid_3.4.4
# [13] gtable_0.3.0       loo_2.1.0          cli_1.1.0          withr_2.1.2
# ...

# %%
#using JuliaRunClient
#initParallel()
# Apparently, no parallel mode for free-tier users
# error: Parallel mode is already being used in a different Julia instance

using RCall;

# %%
# 4 threads (1 core) time shown
#   user  system elapsed 
#  2.511   0.000   2.528 
#
# 1 thread (1 core) time shown
#   user  system elapsed 
#  2.287   0.007   2.321 
#
# 1 thread (2 cores - but ?Juliabox cannot start 2 workers, so take longer time) time shown
#   user  system elapsed 
#  3.203   0.000   3.202
#
# 1 thread (1 core) time shown
#   with cores = 2 in stan()
# kernel simply died!!!


cd("/mnt/juliabox/JuliaBox_Sync")
R"""

.libPaths(c("/mnt/juliabox/R_library", .libPaths()))
print(.libPaths())
print(sessionInfo())

library(magrittr)

library(rstan)
# The following can affect distributional computing over a cluster
#options(mc.cores = 2)  # only 1 core on Juliabox; don't set more unless 2-core machine is launched

source("/mnt/juliabox/JuliaBox_Sync/tryStan_2.R")
""";
# Out:
# [1] "/mnt/juliabox/R_library"       "/usr/local/lib/R/site-library"
# [3] "/usr/lib/R/site-library"       "/usr/lib/R/library"
# R version 3.4.4 (2018-03-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 16.04.5 LTS
#
# Matrix products: default
# BLAS: /usr/lib/libblas/libblas.so.3.6.0
# LAPACK: /usr/lib/lapack/liblapack.so.3.6.0
#
# locale:
# [1] C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] rstan_2.18.2       StanHeaders_2.18.1 ggplot2_3.1.0      magrittr_1.5
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.1         tidyselect_0.2.5   munsell_0.5.0      colorspace_1.4-1
#  [5] R6_2.4.0           rlang_0.3.3        plyr_1.8.4         dplyr_0.8.0.1
#  [9] parallel_3.4.4     pkgbuild_1.0.3     grid_3.4.4         gtable_0.3.0
# [13] loo_2.1.0          cli_1.1.0          withr_2.1.2        matrixStats_0.54.0
# ...
